# %% [markdown]
# ### **Создание Series**

# %%
import pandas as pd
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)

display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
print(countries.loc['US'])
print(countries.loc[['US', 'RU', 'UK']])
print(countries.iloc[6])
print(countries.iloc[1:4])
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object
# США
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object
# Казахстан
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object

# %% [markdown]
# #### Задача 2.4

# %% [markdown]
# В аптеку поступают партии лекарств. Их названия находятся в списке names, количество единиц товара находится в списке counts.
#
# Например:
# names = ['chlorhexidine', 'cyntomycin', 'afobazol'] counts = [15, 18, 7]
#
# Напишите функцию create_medications(names, counts), которая создает Series medications, индексами которой являются названия лекарств names, а значениями - их количество в поставке counts.
#
# А также напишите функцию get_percent(medications, name), которая возвращает долю количества товара с именем name от общего количества товаров в поставке в процентах.

# %%
#Вариант ALD

import pandas as pd
import numpy as np

def create_medications(names, counts):
    series_medications = pd.Series(
        data = counts,
        index = names,
        name = 'series_medications'
    )
    return series_medications

def get_percent(medications, name):
    name_count = medications.loc[name]
    sum_series = medications.sum()
    percentage = name_count / sum_series * 100
    return percentage

names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]
medications = create_medications(names, counts)

print(get_percent(medications, "chlorhexidine"))

print(get_percent(name = 'cyntomycin', medications = create_medications(['chlorhexidine', 'cyntomycin', 'afobazol'],[26, 18, 7])))
# Out:
# 37.5
# 35.294117647058826

# %%
#Вариант SF

import pandas as pd

def create_medications(names, counts):
    medications = pd.Series(index=names, data=counts)
    return medications
def get_percent(medications, name):
    return(medications.loc[name]/sum(medications) * 100)

# %% [markdown]
# ### **Создание DataFrame**

# %%
import pandas as pd

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']

display(countries_df)
countries_df.mean(axis=0, numeric_only=True) # суммирование по столбцу
countries_df.mean(axis=1, numeric_only=True) # суммирование по строке
countries_df.population # Можно обратиться к DataFrame по имени столбца через точку. !!! Однако использование такого способа возможно только тогда, когда имя столбца указано без пробелов.
countries_df['population'] # Другой вариант — обратиться к DataFrame по индексу и указать имя столбца
type(countries_df.population)
countries_df.loc['UK', 'square'] # Получение данных - сначала вводим индекс (название строки), затем имя столбца
countries_df.loc['RU', ['population', 'square']] # Получение нескольких данных по одному индексу
countries_df.loc[['UA', 'BY', 'KZ'], ['population', 'square']] # Получение нескольких данных по нескольким индексам
countries_df.iloc[4:8, 1:3] # Отсчет начинается без учета названий столбцов и строк
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %% [markdown]
# #### Задача 3.5
#
# Вы работаете аналитиком в компании ScienceYou. Ваша задача — проанализировать чистую прибыль.
#
# Доходы (income), расходы (expenses) и годы (years), соответствующие им, предоставлены вам в виде списков.
# Например:
# income = [478, 512, 196]
# expenses = [156, 130, 270]
# years = [2018, 2019, 2020]
#
# Создайте функцию create_companyDF(income, expenses, years), которая возвращает DataFrame, составленный из входных данных со столбцами Income и Expenses и индексами, соответствующими годам рассматриваемого периода.
# Пример такого DataFrame представлен ниже.
#     Income  Expenses
# 2018    478     156
# 2019    512     130
# 2020    196     270
#
# Также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанными в таблице df, за год year.
#
# Примечание. Если информация за запрашиваемый год не указана в вашей таблице, вам необходимо вернуть None.

# %%
# Вариант ALD

def create_companyDF(income, expenses, years):
    companyDF = pd.DataFrame({
        'Income': income,
        'Expenses': expenses,
   })
    companyDF.index = years
    return companyDF

def get_profit(df, year):
    df2 = df.index.tolist() # Переводим индексы в список, чтобы проверить имеется ли указанный год в таблице
    if year in df2:
        diff = df.loc[year, 'Income'] - df.loc[year, 'Expenses']
        return diff
    else: return None
        

income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]
df = create_companyDF(income, expenses, years)


print(get_profit(year = 2018, df = create_companyDF([612, 516, 329, 158], [136,163,250,361], [2017,2018,2019,2020])))

display(create_companyDF(income, expenses, years))
display(get_profit(df, 2017))
# Out:
# 353
#       Income  Expenses
# 2018     478       156
# 2019     512       130
# 2020     196       270
# None

# %%
# Вариант SF

import pandas as pd

def create_companyDF(income, expenses, years):
    df = pd.DataFrame({
        'Income': income,
        'Expenses': expenses
        },
        index = years
    )
    return df

def get_profit(df, year):
    if year in df.index:
        profit = df.loc[year, 'Income'] - df.loc[year, 'Expenses']
    else:
        profit=None
    return profit

print(get_profit(year = 2018, df = create_companyDF([612, 516, 329, 158], [136,163,250,361], [2017,2018,2019,2020])))
display(get_profit(df, 2017))
# Out:
# 353
# None

# %% [markdown]
# ### **Работа с различными источниками данных в Pandas**

# %%
import pandas as pd
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')
countries_df.to_excel('data/countries1.xlsx', index=False)

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';')
display(countries_data)
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
countries1_data = pd.read_excel('data/countries1.xlsx')
display(countries1_data)
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %% [markdown]
# ### **Знакомимся с данными: недвижимость**

# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
display(melb_data.loc[15])
display(melb_data.loc[90, "Date"])
display(melb_data.loc[3521])
display(melb_data.loc[1690])
display(melb_data.loc[3521, "Landsize"] / melb_data.loc[1690, "Landsize"])
display(melb_data.head(5))
display(melb_data.tail(7))
display(melb_data.shape) # Выодет форму таблицы - сколько строк и столбцов
melb_data['Car'] = melb_data['Car'].astype('int64') # Изменение типа данных
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
display(melb_data.info()) # Получение данных о таблица, какие строки есть и т.д.
display(melb_data.describe().loc[:, ['Distance', 'BuildingArea', 'Price']]) # Получение статистических данных (можно по конкретным столбцам) 
display(melb_data.describe(include=['object'])) # Вывести сведения по столбцам - количество непустых, кол уникальных, топовый и сколько раз повторяется топовый 
display(melb_data['Regionname'].value_counts()) # Вывести сведения по частоте упоминаний объектов по столбцам
display(melb_data['Regionname'].value_counts(normalize=True)) # Вывести сведения по частоте упоминаний объектов по столбцам в виде долей
display(melb_data['Type'].value_counts(normalize=True))
# Out:
#        index         Suburb           Address  Rooms Type      Price Method
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S  \
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %% [markdown]
# ### **Агрегирующие методы**

# %% [markdown]
# .count()	Количество непустых значений
# .mean()	Среднее значение
# .min()	Минимальное значение
# .max()	Максимальное значение
# .var()	Дисперсия
# .std()	Стандартное отклонение
# .sum()	Сумма
# .quantile(x)	Квантиль уровня x
# .nunique()	Число уникальных значений

# %%
print(melb_data['Price'].mean())
print(melb_data['Car'].max())
rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))

landsize_median = melb_data['Landsize'].median()
landsize_mean = melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean) / landsize_mean)

print(melb_data['Rooms'].mode())
print(melb_data['Regionname'].mode())

display(melb_data['Propertycount'].value_counts())

BuildingArea_median = melb_data['BuildingArea'].median()
BuildingArea_mean = melb_data['BuildingArea'].mean()
print(abs(BuildingArea_median - BuildingArea_mean) / BuildingArea_mean)

print(melb_data['Rooms'].nunique())

display(melb_data['Bedroom'].value_counts())
# Out:
# 1075684.079455081
# 10
# Total income of real estate agencies: 1752934775.88
# 0.21205713983546193
# 0    3
# Name: Rooms, dtype: int64
# 0    Southern Metropolitan
# Name: Regionname, dtype: object
# Propertycount
# 21650    359
# 8870     298
# 14949    260
# 10969    249
# 14577    239
#         ...
# 1721       1
# 249        1
# 2493       1
# 1863       1
# 1424       1
# Name: count, Length: 311, dtype: int64
# 0.09764079662364533
# 9
# Bedroom
# 3     5896
# 2     3737
# 4     2601
# 1      691
# 5      556
# 6       63
# 0       16
# 7       10
# 8        5
# 9        3
# 20       1
# 10       1
# Name: count, dtype: int64

# %% [markdown]
# ### **Фильтрация данных**

# %%
mask = melb_data['Price'] > 2000000
display(mask)
display(melb_data[mask].head())

# Примечание. В результате выполнения фильтрации возвращается новый DataFrame, 
# полученный из исходного, при этом исходная таблица melb_data остаётся без изменений.

# При этом, не обязательно заносить маску в отдельную переменную 
display(melb_data[melb_data['Price'] > 2000000].head())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool
#     index       Suburb               Address  Rooms Type      Price Method
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI  \
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea
# 80    Buxton   4/03/2017       3.3  ...    0     211.0         198.0  \
# 85  Marshall   7/05/2016       3.3  ...    1     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...    1     199.0         107.0
# ...

# %%
melb_data[melb_data['Rooms'] == 3].shape # Если не указывать в скобках индекс, то выведет кортеж
melb_data[melb_data['Rooms'] == 3].shape[0]
# Out:
# 5881

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 3

# %%
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 68

# %%
melb_data[melb_data['Type'] == 't']['Rooms'].max()
# Out:
# 5

# %%
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# 126.0

# %%
# У скольких объектов недвижимости из таблицы melb_data отсутствуют ванные комнаты?

no_bathroom = melb_data['index'].count() - melb_data[melb_data['Bathroom'] >= 1].shape[0]

print(melb_data['index'].count())
print(melb_data[melb_data['Bathroom'] >= 1].shape[0])
print(no_bathroom)
# Out:
# 13580
# 13546
# 34

# %%
# Сколько в таблице melb_data объектов недвижимости, 
# которые были проданы риелторской компанией Nelson и стоимость которых составила больше 3 миллионов?

melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0]
# Out:
# 5

# %%
melb_data[melb_data['BuildingArea'] == 0]['Price'].min()
# Out:
# 412500.0

# %%
# Какова средняя цена объектов недвижимости в таблице melb_data с ценой менее одного миллиона, 
# в которых либо количество комнат больше пяти, либо здание моложе 2015 года?

round(melb_data[(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015))]['Price'].mean(), 0)
# Out:
# 769239.0

# %%
# В каком районе Мельбурна чаще всего продаются виллы и коттеджи (тип здания — h) с ценой меньше трёх миллионов?

new_table = melb_data[(melb_data['Price'] < 3000000) & (melb_data['Type'] == 'h')]
new_table['Regionname'].value_counts()
# Out:
# Regionname
# Northern Metropolitan         2737
# Southern Metropolitan         2520
# Western Metropolitan          2286
# Eastern Metropolitan          1167
# South-Eastern Metropolitan     387
# Eastern Victoria                50
# Northern Victoria               41
# Western Victoria                32
# Name: count, dtype: int64
